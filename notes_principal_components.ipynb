# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import NMF

from playervectors import PlayerHeatMap
from ExtractData import ExtractCoordinates, ExtractPlayers, ExtractTeams, ExtractMinutesPlayed, ExtractGoalkeepers, CalcPlayingDirection, NormalizeDirection

# %% [markdown]
# ## Load: Players

# %%
df_players = pd.read_csv('event_streams/players.csv')
df_players.head()
# Out:
#                                         passportArea  weight  \
# 0  {'name': 'Turkey', 'id': '792', 'alpha3code': ...      78
# 1  {'name': 'Senegal', 'id': '686', 'alpha3code':...      73
# 2  {'name': 'France', 'id': '250', 'alpha3code': ...      72
# 3  {'name': 'Senegal', 'id': '686', 'alpha3code':...      82
# 4  {'name': 'France', 'id': '250', 'alpha3code': ...      84
#
#            firstName  middleName     lastName  currentTeamId   birthDate  \
# 0              Harun         NaN        Tekin         4502.0  1989-06-17
# 1             Malang         NaN         Sarr         3775.0  1999-01-23
# 2               Over         NaN     Mandanda         3772.0  1998-10-26
# 3  Alfred John Momar         NaN      N'Diaye          683.0  1990-03-06
# 4           Ibrahima         NaN  Konat\u00e9         2975.0  1999-05-25
#
#    height                                               role  \
# 0     187  {'code2': 'GK', 'code3': 'GKP', 'name': 'Goalk...
# ...

# %% [markdown]
# #### Extract Player Information

# %%
# Extract Players
# Mapping {playerID -> [list of selected attributes]}
players = ExtractPlayers(df=df_players, wy_id='wyId', attributes=['firstName', 'lastName', 'currentTeamId'])

# %%
df_playerank = pd.read_csv('event_streams/playerank.csv')
df_playerank.head()
# Out:
#    goalScored  playerankScore  matchId  playerId roleCluster  minutesPlayed
# 0           0          0.0053  2057991     10014    right CB             90
# 1           0          0.0009  2057992     10014    right CB             41
# 2           0         -0.0013  2057998    100140  central MF             90
# 3           0          0.0031  2058000    100140     left CB             90
# 4           0          0.0035  2499869     10108    right CB             90

# %% [markdown]
# #### Extract Goalkeepers

# %%
keepers = ExtractGoalkeepers(df_players)

# %% [markdown]
# #### Extract Played Minutes

# %%
# Extract played minutes
# Mapping {playerID -> minutes}
minutes_played = ExtractMinutesPlayed(df=df_playerank, column_player='playerId', column_minutes='minutesPlayed')

# %% [markdown]
# ## Load: Event Streams

# %%
# df_events = pd.read_csv('data/events_GermanyExample.csv')
df_events = pd.read_csv('event_streams/actions.csv')
df_events.head()
# Out:
#    Unnamed: 0  game_id  period_id  time_seconds  team_id  player_id  start_x  \
# 0           0  2500089          1      2.763597     1659       9637    52.50
# 1           1  2500089          1      4.761353     1659       8351    63.00
# 2           2  2500089          1      5.533097     1659       9285    64.05
# 3           3  2500089          1      7.707561     1659     239411    72.45
# 4           4  2500089          1     11.614943     1659       9637    35.70
#
#    start_y  end_x  end_y  original_event_id  bodypart_id  type_id  result_id  \
# 0    34.00  63.00  30.60        251700146.0            0        0          1
# 1    30.60  64.05  10.20        251700147.0            0        0          1
# 2    10.20  72.45  20.40        251700148.0            0        0          1
# 3    20.40  35.70  19.04        251700161.0            0        0          1
# 4    19.04  30.45  12.24        251700149.0            0        0          1
#
# ...

# %% [markdown]
# #### Normalize Playing Direction

# %%
df_events['start_x'] = 100 - df_events['start_x']
df_events['start_y'] = 100 - df_events['start_y']

# %% [markdown]
# #### Select Relevant Actions with respect to thier x,y coordinates

# %%
# {action -> {playerID -> ([list of x coordinates], [list of y coordinates])}}
# We select here: Shot, Pass, Cross, Duell
coordinates = ExtractCoordinates(df=df_events, column_player_id='player_id', column_event_name='type_name', column_x='start_x', column_y='start_y', actions=['pass', 'cross', 'dribble', 'shot'])

# %% [markdown]
# ## Load: Teams

# %%
df_teams = pd.read_csv('event_streams/teams.csv')
df_teams.head()
# Out:
#                   city                   name  wyId  \
# 0  Newcastle upon Tyne       Newcastle United  1613
# 1                 Vigo          Celta de Vigo   692
# 2            Barcelona               Espanyol   691
# 3      Vitoria-Gasteiz  Deportivo Alav\u00e9s   696
# 4             Valencia                Levante   695
#
#                    officialName  \
# 0           Newcastle United FC
# 1       Real Club Celta de Vigo
# 2  Reial Club Deportiu Espanyol
# 3         Deportivo Alav\u00e9s
# 4                    Levante UD
#
#                                                 area  type
# 0  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 1  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 2  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 3  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 4  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club

# %% [markdown]
# #### Extract Team Information

# %%
# Extracting Team Information
# Mapping {teamID -> [selected attributes e.g. TeamName, City, ...]}
teams = ExtractTeams(df=df_teams, wy_id='wyId', attributes=['name'])

# %%
# Mapping {teamID -> [list of playerIDs]}
teamID_to_playerIDs = {}

# Mapping {playerID -> Player Name}
playersID_to_name = {}

for playerID, attributes in players.items():
    first, last, teamID = attributes[0], str(attributes[1]), str(attributes[2])
    
    if teamID not in teamID_to_playerIDs:
        teamID_to_playerIDs[teamID] = [playerID]
    else:
        teamID_to_playerIDs[teamID].append(playerID)
    
    if playerID not in playersID_to_name:
        playersID_to_name[playerID] = f'{first} {last}'

# %% [markdown]
# ## Visualizing Principal Components for Actions: shot, pass, cross, dribble

# %% [markdown]
# ## Principal Components for Action: shot

# %%
# ------------------------------------------------------
# Hyperparameters:
grid = (50, 50)         # Grid dimensions
sigma = 3.0             # Sigma for gaussian blur
action = 'shot'         # Relevant action 'a'
k_components = 4        # Number of principle components for action 'a'
init_nmf = 'nndsvd'     # NMF initialization parameter
random_nmf = 42         # NMF random sate

# ------------------------------------------------------
# (1): Calculate heatmaps (for every player for selected action 'a')

playerID_to_heatmap = {}
for playerID, pairXY in list(coordinates[action].items()):
    x, y = pairXY[0], pairXY[1] 

    # Check for played minutes 
    minutes = 0.0 
    if playerID in minutes_played: 
        minutes = minutes_played[playerID] 

    # Check for player name
    player_name = None
    if playerID in playersID_to_name:
        player_name = playersID_to_name[playerID]

    # Build Player-Vectors
    heatmap = PlayerHeatMap(shape=grid,
                            player_name=player_name,
                            player_id=playerID,
                            action_name=action,
                            sigma=sigma)
    
    # Counting + Normalizing + Smoothing
    heatmap.fit(x, y, minutes)

    # NOTE: Ignoring goalkeepers
    # if playerID not in keepers: 
    #    playerID_to_heatmap[playerID] = heatmap
    playerID_to_heatmap[playerID] = heatmap

# ------------------------------------------------------
# (2): Reshape heatmaps

# Calculate matrix M
M = []
num_players = len(playerID_to_heatmap)
for _, X in playerID_to_heatmap.items():
    X_reshape = X.heatmap_.reshape(grid[0] * grid[1], 1)
    M.append(X_reshape)
# M = np.array(M).reshape(grid[0] * grid[1], num_players)
M = np.array(M).reshape(num_players, grid[0] * grid[1]).T
print(f'Number of Players: {num_players}')
print(f'M shape: {M.shape}')
# Out:
# Number of Players: 2374
# M shape: (2500, 2374)

# %% [markdown]
# #### Using NMF

# %%
model = NMF(n_components=k_components, init=init_nmf, random_state=random_nmf, max_iter=500)
W = model.fit_transform(M)
H = model.components_
print(f'Shape of W: {W.shape}')
print(f'Shape of H: {H.shape}')
# Out:
# Shape of W: (2500, 4)
# Shape of H: (4, 2374)

# %%
print(f'Shape of W: {W.shape}')
print(f'Shape of H: {H.shape}')
# Out:
# Shape of W: (2500, 4)
# Shape of H: (4, 2374)

# %% [markdown]
# #### Plotting principle components

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(16, 8))
for k in range(k_components):
    W_k = W.T[k]
    W_k = W_k.reshape(grid[0], grid[1])
    ax = axes[k // 2, k % 2]
    sns.heatmap(W_k, ax=ax, cbar=True)
    ax.set_title(f'{action} Component {k + 1}')
plt.show()

# %% [markdown]
# ## Principle Components for Action: cross

# %%
# ------------------------------------------------------
# Hyperparameters:
grid = (50, 50)         # Grid dimensions
sigma = 3.0             # Sigma for gaussian blur
action = 'cross'        # Relevant action 'a'
k_components = 4        # Number of principle components for action 'a'
init_nmf = 'nndsvd'     # NMF initialization parameter
random_nmf = 42         # NMF random sate

# ------------------------------------------------------
# (1): Calculate heatmaps (for every player for selected action 'a')

playerID_to_heatmap = {}
for playerID, pairXY in list(coordinates[action].items()):
    x, y = pairXY[0], pairXY[1] 

    # Check for played minutes 
    minutes = 0.0 
    if playerID in minutes_played: 
        minutes = minutes_played[playerID] 

    # Check for player name
    player_name = None
    if playerID in playersID_to_name:
        player_name = playersID_to_name[playerID]

    # Build Player-Vectors
    heatmap = PlayerHeatMap(shape=grid,
                            player_name=player_name,
                            player_id=playerID,
                            action_name=action,
                            sigma=sigma)
    
    # Counting + Normalizing + Smoothing
    heatmap.fit(x, y, minutes)

    # NOTE: Ignoring goalkeepers
    if playerID not in keepers: 
        playerID_to_heatmap[playerID] = heatmap


# ------------------------------------------------------
# (2): Reshape heatmaps

# Calculate matrix M
M = []
num_players = len(playerID_to_heatmap)
for _, X in playerID_to_heatmap.items():
    X_reshape = X.heatmap_.reshape(grid[0] * grid[1], 1)
    M.append(X_reshape)
M = np.array(M).reshape(num_players, grid[0] * grid[1]).T
print(f'Number of Players: {num_players}')
print(f'M shape: {M.shape}')
# Out:
# Number of Players: 2344
# M shape: (2500, 2344)

# %% [markdown]
# #### Using NMF

# %%
model = NMF(n_components=k_components, init=init_nmf, random_state=random_nmf, max_iter=500)
W = model.fit_transform(M)
H = model.components_
print(f'Shape of W: {W.shape}')
print(f'Shape of H: {H.shape}')
# Out:
# Shape of W: (2500, 4)
# Shape of H: (4, 2344)

# %% [markdown]
# #### Plotting principle components

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(16, 8))
for k in range(k_components):
    W_k = W.T[k]
    W_k = W_k.reshape(grid[0], grid[1])
    ax = axes[k // 2, k % 2]
    sns.heatmap(W_k, ax=ax, cbar=True)
    ax.set_title(f'{action} Component {k + 1}')
plt.show()

# %% [markdown]
# ### Principle Components for Action: pass

# %%
# ------------------------------------------------------
# Hyperparameters:
grid = (50, 50)         # Grid dimensions
sigma = 3.0             # Sigma for gaussian blur
action = 'pass'         # Relevant action 'a'
k_components = 5        # Number of principle components for action 'a'
init_nmf = 'nndsvd'     # NMF initialization parameter
random_nmf = 42         # NMF random sate

# ------------------------------------------------------
# (1): Calculate heatmaps (for every player for selected action 'a')

playerID_to_heatmap = {}
for playerID, pairXY in list(coordinates[action].items()):
    x, y = pairXY[0], pairXY[1] 

    # Check for played minutes 
    minutes = 0.0 
    if playerID in minutes_played: 
        minutes = minutes_played[playerID] 

    # Check for player name
    player_name = None
    if playerID in playersID_to_name:
        player_name = playersID_to_name[playerID]

    # Build Player-Vectors
    heatmap = PlayerHeatMap(shape=grid,
                            player_name=player_name,
                            player_id=playerID,
                            action_name=action,
                            sigma=sigma)
    
    # Counting + Normalizing + Smoothing
    heatmap.fit(x, y, minutes)

    # NOTE: Ignoring goalkeepers
    if playerID not in keepers:
        playerID_to_heatmap[playerID] = heatmap

# ------------------------------------------------------
# (2): Reshape heatmaps

# Calculate matrix M
M = []
num_players = len(playerID_to_heatmap)
for _, X in playerID_to_heatmap.items():
    X_reshape = X.heatmap_.reshape(grid[0] * grid[1], 1)
    M.append(X_reshape)
M = np.array(M).reshape(num_players, grid[0] * grid[1]).T
print(f'Number of Players: {num_players}')
print(f'M shape: {M.shape}')
# Out:
# Number of Players: 2797
# M shape: (2500, 2797)

# %% [markdown]
# #### Using NMF

# %%
model = NMF(n_components=k_components, init=init_nmf, random_state=random_nmf, max_iter=500)
W = model.fit_transform(M)
H = model.components_
print(f'Shape of W: {W.shape}')
print(f'Shape of H: {H.shape}')
# Out:
# Shape of W: (2500, 5)
# Shape of H: (5, 2797)

# %%
print(f'Number of Players: {num_players}')
print(f'A shape: {M.shape}')
# Out:
# Number of Players: 2797
# A shape: (2500, 2797)

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(16, 8))
for k in range(k_components):
    W_k = W.T[k]
    W_k = W_k.reshape(grid[0], grid[1])
    ax = axes[k // 2, k % 2]
    sns.heatmap(W_k, ax=ax, cbar=True)
    ax.set_title(f'{action} Component {k + 1}')
    plt.tight_layout()
plt.show()

# %% [markdown]
# ### Principle Components for Action: dribble

# %%
# ------------------------------------------------------
# Hyperparameters:
grid = (50, 50)         # Grid dimensions
sigma = 3.0             # Sigma for gaussian blur
action = 'dribble'      # Relevant action 'a'
k_components = 5        # Number of principle components for action 'a'
init_nmf = 'nndsvd'     # NMF initialization parameter
random_nmf = 42         # NMF random sate

# ------------------------------------------------------
# (1): Calculate heatmaps (for every player for selected action 'a')

playerID_to_heatmap = {}
for playerID, pairXY in list(coordinates[action].items()):
    x, y = pairXY[0], pairXY[1] 

    # Check for played minutes 
    minutes = 0.0 
    if playerID in minutes_played: 
        minutes = minutes_played[playerID] 

    # Check for player name
    player_name = None
    if playerID in playersID_to_name:
        player_name = playersID_to_name[playerID]

    # Build Player-Vectors
    heatmap = PlayerHeatMap(shape=grid,
                            player_name=player_name,
                            player_id=playerID,
                            action_name=action,
                            sigma=sigma)
    
    # Counting + Normalizing + Smoothing
    heatmap.fit(x, y, minutes)


    playerID_to_heatmap[playerID] = heatmap

    # NOTE: Ignoring goalkeepers
    if playerID not in keepers:
        playerID_to_heatmap[playerID] = heatmap

# ------------------------------------------------------
# (2): Reshape heatmaps

# Calculate matrix M
M = []
num_players = len(playerID_to_heatmap)
for _, X in playerID_to_heatmap.items():
    X_reshape = X.heatmap_.reshape(grid[0] * grid[1], 1)
    M.append(X_reshape)
M = np.array(M).reshape(num_players, grid[0] * grid[1]).T
print(f'Number of Players: {num_players}')
print(f'M shape: {M.shape}')
# Out:
# Number of Players: 2895
# M shape: (2500, 2895)

# %% [markdown]
# #### Using NMF

# %%
model = NMF(n_components=k_components, init=init_nmf, random_state=random_nmf, max_iter=500)
W = model.fit_transform(M)
H = model.components_
print(f'Shape of W: {W.shape}')
print(f'Shape of H: {H.shape}')
# Out:
# Shape of W: (2500, 5)
# Shape of H: (5, 2895)

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(16, 8))
for k in range(k_components):
    W_k = W.T[k]
    W_k = W_k.reshape(grid[0], grid[1])
    ax = axes[k // 2, k % 2]
    sns.heatmap(W_k, ax=ax, cbar=True)
    ax.set_title(f'{action} Component {k + 1}')
plt.show()
